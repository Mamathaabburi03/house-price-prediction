# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    'Area': [1000, 1500, 2000, 2500, 3000],
    'Bedrooms': [2, 3, 3, 4, 4],
    'Price': [3000000, 4500000, 5000000, 6500000, 8000000]
}

df = pd.DataFrame(data)

df
# Out:
#    Area  Bedrooms    Price
# 0  1000         2  3000000
# 1  1500         3  4500000
# 2  2000         3  5000000
# 3  2500         4  6500000
# 4  3000         4  8000000

# %%
X = df[['Area', 'Bedrooms']]
y = df['Price']

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[2200, 3]])

print("Predicted House Price:", prediction[0])
# Out:
# Predicted House Price: 5746666.666666667
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(df['Area'], df['Price'])
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("House Price Prediction")
plt.show()

# %%
area = int(input("Enter Area: "))
bedrooms = int(input("Enter Bedrooms: "))

result = model.predict([[area, bedrooms]])

print("Estimated House Price:", result[0])
# Out:
# Enter Area: 2200
# Enter Bedrooms: 3
# Estimated House Price: 5746666.666666667
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
score = model.score(X, y)

print("Model Accuracy:", score)
# Out:
# Model Accuracy: 0.981859410430839
